# %%
import torchvision.models as models
import torch
from ptflops import get_model_complexity_info

with torch.cuda.device(0):
  net = models.densenet161()

  macs, params = get_model_complexity_info(net, (3, 224, 224), as_strings=True, backend='aten',
                                           print_per_layer_stat=True, verbose=True)
  print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
  print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.max_pool2d_with_indices operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.avg_pool2d operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.avg_pool2d operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.avg_pool2d operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.cat operation is treated as a zero-op
# Warning: aten.empty operation is treated as a zero-op
# Warning: aten.native_batch_norm operation is treated as a zero-op
# Warning: aten.relu_ operation is treated as a zero-op
# Warning: aten.detach operation is treated as a zero-op
# Warning: aten.mean operation is treated as a zero-op
# Warning: aten.view operation is treated as a zero-op
# Warning: aten.t operation is treated as a zero-op
# Total:7.73 GMac
# Module:  Global
# aten.convolution: 7.73 GMac
# aten.addmm: 2.21 MMac
#
# Module:  features
# aten.convolution: 7.73 GMac
#
# Module:  classifier
# aten.addmm: 2.21 MMac
#
# Computational complexity:       7.73 GMac
# Number of parameters:           28.68 M
